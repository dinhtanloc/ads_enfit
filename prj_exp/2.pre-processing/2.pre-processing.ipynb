# %%
import sys,os
__script_path=os.path.abspath(globals().get('__file__','.'))
__script_dir = os.path.dirname(__script_path)
root_dir = os.path.abspath(f'{__script_dir}/../')
print(root_dir)
for lib in [root_dir][::-1]:
    if lib in sys.path:
        sys.path.remove(lib)
    sys.path.insert(0,lib)
# Out:
# c:\Users\PC\Data\ads_enfit

# %%
from libs.common import *
from config.config import *

# %%
if os.path.exists(exps_dir) == False: # tạo thư mục (nếu chưa có)
  os.makedirs(exps_dir, exist_ok=True)

save_dir = f"{exps_dir}/prj_exp"
os.makedirs(save_dir, exist_ok=True)

# %%
df_train_features=pd.read_csv(f'{save_dir}/df_train_features.csv')
df_test_features=pd.read_csv(f'{save_dir}/df_test_features.csv')
df_train_features
# Out:
#           row_id  county  is_business  product_type  is_consumption  \
# 0         366048       0            0             1               0
# 1         366049       0            0             1               1
# 2         366050       0            0             2               0
# 3         366051       0            0             2               1
# 4         366052       0            0             3               0
# ...          ...     ...          ...           ...             ...
# 1651897  2018347      15            1             0               1
# 1651898  2018348      15            1             1               0
# 1651899  2018349      15            1             1               1
# 1651900  2018350      15            1             3               0
# 1651901  2018351      15            1             3               1
#
#                     datetime        date  eic_count  installed_capacity  \
# 0        2022-01-01 00:00:00  2022-01-01      148.0             1345.69
# 1        2022-01-01 00:00:00  2022-01-01      148.0             1345.69
# 2        2022-01-01 00:00:00  2022-01-01       16.0              153.70
# 3        2022-01-01 00:00:00  2022-01-01       16.0              153.70
# 4        2022-01-01 00:00:00  2022-01-01      739.0             7638.62
# ...                      ...         ...        ...                 ...
# 1651897  2023-05-31 23:00:00  2023-05-31       15.0              620.00
# 1651898  2023-05-31 23:00:00  2023-05-31       20.0              624.50
# 1651899  2023-05-31 23:00:00  2023-05-31       20.0              624.50
# 1651900  2023-05-31 23:00:00  2023-05-31       55.0             2188.20
# 1651901  2023-05-31 23:00:00  2023-05-31       55.0             2188.20
#
#          euros_per_mwh  ...  day  weekday  month  year   segment  \
# 0                65.76  ...    1        6      1  2022   0_0_1_0
# 1                65.76  ...    1        6      1  2022   0_0_1_1
# 2                65.76  ...    1        6      1  2022   0_0_2_0
# 3                65.76  ...    1        6      1  2022   0_0_2_1
# 4                65.76  ...    1        6      1  2022   0_0_3_0
# ...                ...  ...  ...      ...    ...   ...       ...
# 1651897          -1.29  ...   31        3      5  2023  15_1_0_1
# 1651898          -1.29  ...   31        3      5  2023  15_1_1_0
# 1651899          -1.29  ...   31        3      5  2023  15_1_1_1
# 1651900          -1.29  ...   31        3      5  2023  15_1_3_0
# 1651901          -1.29  ...   31        3      5  2023  15_1_3_1
#
#          sin(dayofyear)  cos(dayofyear)  sin(hour)  cos(hour)   target
# 0              0.017166        0.999853   0.000000   1.000000    0.000
# 1              0.017166        0.999853   0.000000   1.000000  442.226
# 2              0.017166        0.999853   0.000000   1.000000    0.000
# 3              0.017166        0.999853   0.000000   1.000000   44.899
# 4              0.017166        0.999853   0.000000   1.000000    0.015
# ...                 ...             ...        ...        ...      ...
# 1651897        0.522133       -0.852864  -0.258819   0.965926  197.233
# 1651898        0.522133       -0.852864  -0.258819   0.965926    0.000
# 1651899        0.522133       -0.852864  -0.258819   0.965926   28.404
# 1651900        0.522133       -0.852864  -0.258819   0.965926    0.000
# 1651901        0.522133       -0.852864  -0.258819   0.965926  196.240
#
# [1651902 rows x 46 columns]

# %%
df_test_features.drop_duplicates(inplace=True)

# %%
df_test_features
# Out:
#        Unnamed: 0  county  is_business  product_type  is_consumption  \
# 0               0       0            0             1               0
# 1               1       0            0             1               1
# 2               2       0            0             2               0
# 3               3       0            0             2               1
# 4               4       0            0             3               0
# ...           ...     ...          ...           ...             ...
# 12475       12475      15            1             0               1
# 12476       12476      15            1             1               0
# 12477       12477      15            1             1               1
# 12478       12478      15            1             3               0
# 12479       12479      15            1             3               1
#
#                   datetime   row_id        date  eic_count  \
# 0      2023-05-28 00:00:00  2005872  2023-05-28        507
# 1      2023-05-28 00:00:00  2005873  2023-05-28        507
# 2      2023-05-28 00:00:00  2005874  2023-05-28         11
# 3      2023-05-28 00:00:00  2005875  2023-05-28         11
# 4      2023-05-28 00:00:00  2005876  2023-05-28       1516
# ...                    ...      ...         ...        ...
# 12475  2023-05-31 23:00:00  2018347  2023-05-31         15
# 12476  2023-05-31 23:00:00  2018348  2023-05-31         20
# 12477  2023-05-31 23:00:00  2018349  2023-05-31         20
# 12478  2023-05-31 23:00:00  2018350  2023-05-31         55
# 12479  2023-05-31 23:00:00  2018351  2023-05-31         55
#
#        installed_capacity  ...  total_precipitation_fl  day  weekday  month  \
# 0                4960.215  ...                     0.0   28        7      5
# 1                4960.215  ...                     0.0   28        7      5
# 2                  34.000  ...                     0.0   28        7      5
# 3                  34.000  ...                     0.0   28        7      5
# 4               15977.560  ...                     0.0   28        7      5
# ...                   ...  ...                     ...  ...      ...    ...
# 12475             620.000  ...                     0.0   31        3      5
# 12476             624.500  ...                     0.0   31        3      5
# 12477             624.500  ...                     0.0   31        3      5
# 12478            2188.200  ...                     0.0   31        3      5
# 12479            2188.200  ...                     0.0   31        3      5
#
#        year   segment  sin(dayofyear)  cos(dayofyear)  sin(hour)  cos(hour)
# 0      2023   0_0_1_0        0.565345       -0.824855   0.000000   1.000000
# 1      2023   0_0_1_1        0.565345       -0.824855   0.000000   1.000000
# 2      2023   0_0_2_0        0.565345       -0.824855   0.000000   1.000000
# 3      2023   0_0_2_1        0.565345       -0.824855   0.000000   1.000000
# 4      2023   0_0_3_0        0.565345       -0.824855   0.000000   1.000000
# ...     ...       ...             ...             ...        ...        ...
# 12475  2023  15_1_0_1        0.522133       -0.852864  -0.258819   0.965926
# 12476  2023  15_1_1_0        0.522133       -0.852864  -0.258819   0.965926
# 12477  2023  15_1_1_1        0.522133       -0.852864  -0.258819   0.965926
# 12478  2023  15_1_3_0        0.522133       -0.852864  -0.258819   0.965926
# 12479  2023  15_1_3_1        0.522133       -0.852864  -0.258819   0.965926
#
# [12480 rows x 46 columns]

# %%
df_train_features=df_train_features.drop(columns=['date', 'datetime'])
df_test_features=df_test_features.drop(columns=['date', 'datetime'])
# df.isnull().sum()
# df_train_features.dropna(inplace=True)
print(df_train_features.shape, df_test_features.shape)
# Out:
# (1651902, 44) (12480, 44)

# %%
df_train_features.isnull().sum()
# Out:
# row_id                                      0
# county                                      0
# is_business                                 0
# product_type                                0
# is_consumption                              0
# eic_count                                2400
# installed_capacity                       2400
# euros_per_mwh                             268
# hours_ahead                                 0
# temperature                                 0
# dewpoint                                    0
# cloudcover_high                             0
# cloudcover_low                              0
# cloudcover_mid                              0
# cloudcover_total                            0
# 10_metre_u_wind_component                   0
# 10_metre_v_wind_component                   0
# direct_solar_radiation                      0
# surface_solar_radiation_downwards           0
# snowfall                                    0
# total_precipitation                         0
# hours_ahead_fl                          24762
# temperature_fl                          24762
# dewpoint_fl                             24762
# cloudcover_high_fl                      24762
# cloudcover_low_fl                       24762
# cloudcover_mid_fl                       24762
# cloudcover_total_fl                     24762
# 10_metre_u_wind_component_fl            24762
# 10_metre_v_wind_component_fl            24762
# direct_solar_radiation_fl               24762
# surface_solar_radiation_downwards_fl    24762
# snowfall_fl                             24762
# total_precipitation_fl                  24762
# day                                         0
# weekday                                     0
# month                                       0
# year                                        0
# segment                                     0
# sin(dayofyear)                              0
# cos(dayofyear)                              0
# sin(hour)                                   0
# cos(hour)                                   0
# target                                      0
# dtype: int64

# %%
df_test_features.isnull().sum()
# Out:
# Unnamed: 0                                0
# county                                    0
# is_business                               0
# product_type                              0
# is_consumption                            0
# row_id                                    0
# eic_count                                 0
# installed_capacity                        0
# euros_per_mwh                             0
# hours_ahead                               0
# temperature                               0
# dewpoint                                  0
# cloudcover_high                           0
# cloudcover_low                            0
# cloudcover_mid                            0
# cloudcover_total                          0
# 10_metre_u_wind_component                 0
# 10_metre_v_wind_component                 0
# direct_solar_radiation                    0
# surface_solar_radiation_downwards         0
# snowfall                                  0
# total_precipitation                       0
# hours_ahead_fl                          192
# temperature_fl                          192
# dewpoint_fl                             192
# cloudcover_high_fl                      192
# cloudcover_low_fl                       192
# cloudcover_mid_fl                       192
# cloudcover_total_fl                     192
# 10_metre_u_wind_component_fl            192
# 10_metre_v_wind_component_fl            192
# direct_solar_radiation_fl               192
# surface_solar_radiation_downwards_fl    192
# snowfall_fl                             192
# total_precipitation_fl                  192
# day                                       0
# weekday                                   0
# month                                     0
# year                                      0
# segment                                   0
# sin(dayofyear)                            0
# cos(dayofyear)                            0
# sin(hour)                                 0
# cos(hour)                                 0
# dtype: int64

# %%
df_test_features
# Out:
#        Unnamed: 0  county  is_business  product_type  is_consumption   row_id  \
# 0               0       0            0             1               0  2005872
# 1               1       0            0             1               1  2005873
# 2               2       0            0             2               0  2005874
# 3               3       0            0             2               1  2005875
# 4               4       0            0             3               0  2005876
# ...           ...     ...          ...           ...             ...      ...
# 12475       12475      15            1             0               1  2018347
# 12476       12476      15            1             1               0  2018348
# 12477       12477      15            1             1               1  2018349
# 12478       12478      15            1             3               0  2018350
# 12479       12479      15            1             3               1  2018351
#
#        eic_count  installed_capacity  euros_per_mwh  hours_ahead  ...  \
# 0            507            4960.215          87.54         46.0  ...
# 1            507            4960.215          87.54         46.0  ...
# 2             11              34.000          87.54         46.0  ...
# 3             11              34.000          87.54         46.0  ...
# 4           1516           15977.560          87.54         46.0  ...
# ...          ...                 ...            ...          ...  ...
# 12475         15             620.000          -1.29         45.0  ...
# 12476         20             624.500          -1.29         45.0  ...
# 12477         20             624.500          -1.29         45.0  ...
# 12478         55            2188.200          -1.29         45.0  ...
# 12479         55            2188.200          -1.29         45.0  ...
#
#        total_precipitation_fl  day  weekday  month  year   segment  \
# 0                         0.0   28        7      5  2023   0_0_1_0
# 1                         0.0   28        7      5  2023   0_0_1_1
# 2                         0.0   28        7      5  2023   0_0_2_0
# 3                         0.0   28        7      5  2023   0_0_2_1
# 4                         0.0   28        7      5  2023   0_0_3_0
# ...                       ...  ...      ...    ...   ...       ...
# 12475                     0.0   31        3      5  2023  15_1_0_1
# 12476                     0.0   31        3      5  2023  15_1_1_0
# 12477                     0.0   31        3      5  2023  15_1_1_1
# 12478                     0.0   31        3      5  2023  15_1_3_0
# 12479                     0.0   31        3      5  2023  15_1_3_1
#
#        sin(dayofyear)  cos(dayofyear)  sin(hour)  cos(hour)
# 0            0.565345       -0.824855   0.000000   1.000000
# 1            0.565345       -0.824855   0.000000   1.000000
# 2            0.565345       -0.824855   0.000000   1.000000
# 3            0.565345       -0.824855   0.000000   1.000000
# 4            0.565345       -0.824855   0.000000   1.000000
# ...               ...             ...        ...        ...
# 12475        0.522133       -0.852864  -0.258819   0.965926
# 12476        0.522133       -0.852864  -0.258819   0.965926
# 12477        0.522133       -0.852864  -0.258819   0.965926
# 12478        0.522133       -0.852864  -0.258819   0.965926
# 12479        0.522133       -0.852864  -0.258819   0.965926
#
# [12480 rows x 44 columns]

# %%
df_train_features.dropna(inplace=True)
df_test_features.dropna(inplace=True)
print(len(df_test_features), len(df_train_features))
# Out:
# 12288 1624478

# %%
# for 'segment' in category_columns:
label_encoder = LabelEncoder()
df_train_features['segment'] = label_encoder.fit_transform(df_train_features['segment'])
df_test_features['segment'] = label_encoder.fit_transform(df_test_features['segment'])

# %%
Y=df_train_features['target']
X=df_train_features.drop('target',axis=1)

# %%
df_train,df_valid = train_test_split(df_train_features, test_size=0.33, random_state=42, shuffle=False)
print(df_train.shape, df_valid.shape, df_test_features.shape)
# Out:
# (1088400, 44) (536078, 44) (12288, 44)

# %%
# df_train_features.to_csv(f'{save_dir}/train_lag{ndays}_pre_processing.csv')
df_train.to_csv(f'{save_dir}/df_train.csv')
df_valid.to_csv(f'{save_dir}/df_valid.csv')

# %%
Y.to_csv(f'{save_dir}/y.csv')
X.to_csv(f'{save_dir}/X.csv')
